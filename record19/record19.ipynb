# %%
#write a python program to read a file line by line and store it into a list
with open("s.txt","r") as file:
    lines=file.readlines()

print("Lines in file:")

print(lines)
# Out:
# Lines in file:
# ['red\n', 'green\n', 'blue\n', 'orange\n', '\n']

# %%
#python program to cody odd lines of one file to other
file1=input("Enter the source file")
file2=input("Enter the destination file")
f1=open(file1,"r")
f2=open(file2,"w")
i=0
for line in f1.readlines():
    i=i+1
    if i%2==0:
        continue
    f2.write(line)
f1.close()
f2.close()
print("odd lines of",file1,"is trasfered to",file2)
# Out:
# Enter the source file s.txt
# Enter the destination file n.txt
# odd lines of s.txt is trasfered to n.txt

# %%
#write a python program to read each row from a given csv file and print a list of strings
import csv
fname=input("Enter the csv file name:")
f1=open(fname,"r")
reader=csv.reader(f1)
for row in reader:
    print(row)
f1.close()
# Out:
# Enter the csv file name: ex.csv
# ['NAME', 'MOB.NO', 'COURSE']
# ['JOBIN', '9645163079', 'MCA']
# ['NIHAD', '9544763566', 'MBA']
# ['SREEHARI', '7306754397', 'MCA']

# %%
#write a python program to read specific column of a given CSV file and print the contents of the colums

import csv
fname=input("enter the CSV file name:")
with open(fname,"r") as f1:
    reader=csv.DictReader(f1)
    print("\nDETAILS:")
    for row in reader:
        print("NAME:",row['NAME']," MOB.NUMBER:",row['MOB.NO'])
# Out:
# enter the CSV file name: ex.csv
# DETAILS:
# NAME: JOBIN  MOB.NUMBER: 9645163079
# NAME: NIHAD  MOB.NUMBER: 9544763566
# NAME: SREEHARI  MOB.NUMBER: 7306754397

# %%
#5. Write a Python program to write a Python dictionary to a csv file. After writing the CSV file read the CSV file and display the content.
import csv
data=[
    {"Name":"jobin","Age":25,"Marks":60},
    {"Name":"nihad","Age":20,"Marks":78},
    {"Name":"sreehari","Age":21,"Marks":91}
]
with open("students_dict.csv","w",newline='') as file:
    fieldnames=["Name","Age","Marks"]
    writer=csv.DictWriter(file,fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(data)
    print("Dictionary data written successfully!")
with open("students_dict.csv","r") as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# Dictionary data written successfully!
# ['Name', 'Age', 'Marks']
# ['jobin', '25', '60']
# ['nihad', '20', '78']
# ['sreehari', '21', '91']
